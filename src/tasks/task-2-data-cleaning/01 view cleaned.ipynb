# %%
import pandas as pd

# %%
crime_df = pd.read_csv('../../data/crime_type_by_year_cleaned.csv', index_col=0)
crime_df
# Out:
#       Territory_Code Territory_Name REATIPS_VICES   Crime_Type        Year  \
# 0                 IT          Italy      MASSMURD  mass murder  2017-01-01
# 1                 IT          Italy      MASSMURD  mass murder  2018-01-01
# 2                 IT          Italy      MASSMURD  mass murder  2019-01-01
# 3                 IT          Italy      MASSMURD  mass murder  2020-01-01
# 4                 IT          Italy      MASSMURD  mass murder  2021-01-01
# ...              ...            ...           ...          ...         ...
# 36979          ITG12        Palermo         USURY        usury  2017-01-01
# 36980          ITG12        Palermo         USURY        usury  2018-01-01
# 36981          ITG12        Palermo         USURY        usury  2019-01-01
# 36982          ITG12        Palermo         USURY        usury  2020-01-01
# 36983          ITG12        Palermo         USURY        usury  2021-01-01
#
#        Number_of_Crime
# 0                   17
# ...

# %%
# unique count in Territory_Name
crime_df['Year'].unique()
# Out:
# array(['2017-01-01', '2018-01-01', '2019-01-01', '2020-01-01',
#        '2021-01-01'], dtype=object)

# %%
# on Year column remove string after -
crime_df['Year'] = crime_df['Year'].str.split('-').str[0]
crime_df['Year'].unique()
# Out:
# array(['2017', '2018', '2019', '2020', '2021'], dtype=object)

# %%
# save to csv
crime_df.to_csv('../../data/crime_type_by_year_cleaned.csv')

# %%
NUTS_df = pd.read_csv('../../data/NUTS_Code_Processed.csv', index_col=0)
NUTS_df
# Out:
#                 Code_1     NUTS_2 Code_2     NUTS_3 Code_3  \
# NUTS_1
# Northwest Italy    ITC   Piemonte   ITC1     Torino  ITC11
# Northwest Italy    ITC   Piemonte   ITC1   Vercelli  ITC12
# Northwest Italy    ITC   Piemonte   ITC1     Biella  ITC13
# Northwest Italy    ITC  Lombardia   ITC4     Varese  ITC41
# Northwest Italy    ITC  Lombardia   ITC4      Pavia  ITC48
# ...                ...        ...    ...        ...    ...
# Central Italy      ITI      Lazio   ITI4    Viterbo  ITI41
# Central Italy      ITI      Lazio   ITI4      Rieti  ITI42
# Central Italy      ITI      Lazio   ITI4       Roma  ITI43
# Central Italy      ITI      Lazio   ITI4     Latina  ITI44
# Central Italy      ITI      Lazio   ITI4  Frosinone  ITI45
#
#                                                      NUTS_2_Images  \
# NUTS_1
# Northwest Italy  https://upload.wikimedia.org/wikipedia/commons...
# Northwest Italy  https://upload.wikimedia.org/wikipedia/commons...
# ...
