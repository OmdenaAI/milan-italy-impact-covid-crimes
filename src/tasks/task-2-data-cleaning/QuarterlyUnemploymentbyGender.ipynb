# %%
# Data Preprocessing UnemploymentbyRegion
import pandas as pd
import numpy as np

# %%
# EDA on quarterly unemployment from 2004_22
df = pd.read_csv('unemployment_quartely_2004-22_clean.csv')

# %%
df.head(100)
# Out:
#     Territory_ID Territory Territory_acr  Gender_ID   Gender  ages from  \
# 0              1     Italy            IT          1    males         15
# 1              1     Italy            IT          1    males         15
# 2              1     Italy            IT          1    males         15
# 3              1     Italy            IT          1    males         15
# 4              1     Italy            IT          1    males         15
# ..           ...       ...           ...        ...      ...        ...
# 95             1     Italy            IT          2  females         15
# 96             1     Italy            IT          2  females         15
# 97             1     Italy            IT          2  females         15
# 98             1     Italy            IT          2  females         15
# 99             1     Italy            IT          2  females         15
#
#     ages to    Year Quarter  Unemployment rate
# 0        24  2004.0   Total          20.664027
# 1        24  2004.0     2.0          21.089639
# 2        24  2004.0     1.0          20.361498
# 3        24  2004.0     4.0          22.135774
# 4        24  2004.0     3.0          19.101695
# ..      ...     ...     ...                ...
# 95       24  2004.0   Total          27.310948
# 96       24  2004.0     2.0          28.927354
# 97       24  2004.0     1.0          27.581100
# 98       24  2004.0     4.0          28.376607
# 99       24  2004.0     3.0          24.424972
#
# [100 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Territory_ID', 'Territory', 'Territory_acr', 'Gender_ID', 'Gender',
#        'ages from', 'ages to', 'Year', 'Quarter', 'Unemployment rate'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13680 entries, 0 to 13679
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Territory_ID       13680 non-null  int64
#  1   Territory          13680 non-null  object
#  2   Territory_acr      13680 non-null  object
#  3   Gender_ID          13680 non-null  int64
#  4   Gender             13680 non-null  object
#  5   ages from          13680 non-null  int64
#  6   ages to            13680 non-null  int64
#  7   Year               13680 non-null  float64
#  8   Quarter            13680 non-null  object
#  9   Unemployment rate  13680 non-null  float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 1.0+ MB

# %%
# Drop columns not needed for EDA
df.drop(columns=['Territory_ID','Territory_acr','Gender_ID'], inplace=True)

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Missing values
df.isnull().sum()
# Out:
# Territory            0
# Gender               0
# ages from            0
# ages to              0
# Year                 0
# Quarter              0
# Unemployment rate    0
# dtype: int64

# %%
# Check for missing values
df['Year'] = df['Year'].astype('int')

# %%
df['Quarter'].value_counts()
# Out:
# Total    2736
# 2.0      2736
# 1.0      2736
# 4.0      2736
# 3.0      2736
# Name: Quarter, dtype: int64

# %%
# Make a Pivot Table based on Quarters
df_pivot = pd.pivot_table(df, values='Unemployment rate', index=['Territory', 'ages from','Gender','ages to', 'Year'], columns=['Quarter'])

# %%
df_pivot = df_pivot.reset_index()

# %%
df_pivot.head(5)
# Out:
# Quarter   Territory  ages from   Gender  ages to  Year        1.0        2.0  \
# 0        Centro (I)         15  females       24  2004  28.270221  29.145744
# 1        Centro (I)         15  females       24  2005  28.015023  23.877914
# 2        Centro (I)         15  females       24  2006  28.145904  25.821481
# 3        Centro (I)         15  females       24  2007  23.704696  17.945794
# 4        Centro (I)         15  females       24  2008  21.346537  23.613878
#
# Quarter        3.0        4.0      Total
# 0        20.403515  25.201805  25.647614
# 1        26.554460  24.612646  25.755701
# 2        22.532402  27.071081  25.927753
# 3        19.927928  26.034254  21.957148
# 4        25.277714  27.767465  24.463689

# %%
# melt the dataframe to combine 1.0, 2.0, 3.0 and 4.0 as one column while Total should be separate
df_melt = pd.melt(df_pivot, id_vars=['Territory', 'Gender', 'ages from', 'ages to', 'Year','Total'], 
                  value_vars=['1.0', '2.0', '3.0', '4.0'], var_name='Quarter', value_name='Unemployment rate')

# %%
df_melt.rename(columns={'Total':'Yearly_TotalUnemploymentRate'},inplace=True)

# %%
df_melt.head(5)
# Out:
#     Territory   Gender  ages from  ages to  Year  \
# 0  Centro (I)  females         15       24  2004
# 1  Centro (I)  females         15       24  2005
# 2  Centro (I)  females         15       24  2006
# 3  Centro (I)  females         15       24  2007
# 4  Centro (I)  females         15       24  2008
#
#    Yearly_TotalUnemploymentRate Quarter  Unemployment rate
# 0                     25.647614     1.0          28.270221
# 1                     25.755701     1.0          28.015023
# 2                     25.927753     1.0          28.145904
# 3                     21.957148     1.0          23.704696
# 4                     24.463689     1.0          21.346537

# %%
# Seperate into regional and national
df_melt['Territory'].value_counts()
# Out:
# Centro (I)     1824
# Italy          1824
# Mezzogiorno    1824
# Nord           1824
# Nord-est       1824
# Nord-ovest     1824
# Name: Territory, dtype: int64

# %%
df_melt['Gender'].value_counts()
# Out:
# females    3648
# males      3648
# total      3648
# Name: Gender, dtype: int64

# %%
# Seperate into National and regional
national_data = df_melt[df_melt['Territory'] == 'Italy']
regional_data = df_melt[df_melt['Territory'] != 'Italy']

# %%
national_data.head(5)
# Out:
#     Territory   Gender  ages from  ages to  Year  \
# 456     Italy  females         15       24  2004
# 457     Italy  females         15       24  2005
# 458     Italy  females         15       24  2006
# 459     Italy  females         15       24  2007
# 460     Italy  females         15       24  2008
#
#      Yearly_TotalUnemploymentRate Quarter  Unemployment rate
# 456                     27.310948     1.0          27.581100
# 457                     27.606126     1.0          28.600660
# 458                     25.461231     1.0          28.335586
# 459                     23.342217     1.0          23.514904
# 460                     24.682553     1.0          24.840614

# %%
regional_data.head(5)
# Out:
#     Territory   Gender  ages from  ages to  Year  \
# 0  Centro (I)  females         15       24  2004
# 1  Centro (I)  females         15       24  2005
# 2  Centro (I)  females         15       24  2006
# 3  Centro (I)  females         15       24  2007
# 4  Centro (I)  females         15       24  2008
#
#    Yearly_TotalUnemploymentRate Quarter  Unemployment rate
# 0                     25.647614     1.0          28.270221
# 1                     25.755701     1.0          28.015023
# 2                     25.927753     1.0          28.145904
# 3                     21.957148     1.0          23.704696
# 4                     24.463689     1.0          21.346537

# %%
# Rename some of the column
national_data = national_data.rename(columns={'Territory':'Country','Unemployment rate':'National_UR'})

# %%
national_data.head(5)
# Out:
#     Country   Gender  ages from  ages to  Year  Yearly_TotalUnemploymentRate  \
# 456   Italy  females         15       24  2004                     27.310948
# 457   Italy  females         15       24  2005                     27.606126
# 458   Italy  females         15       24  2006                     25.461231
# 459   Italy  females         15       24  2007                     23.342217
# 460   Italy  females         15       24  2008                     24.682553
#
#     Quarter  National_UR
# 456     1.0    27.581100
# 457     1.0    28.600660
# 458     1.0    28.335586
# 459     1.0    23.514904
# 460     1.0    24.840614

# %%
regional_data = regional_data.rename(columns={'Territory':'Region','Unemployment rate':'Regional_UR'})

# %%
merged_df = pd.merge(regional_data, national_data, on=['Gender', 'ages from', 'ages to', 'Year', 'Quarter'], how='outer', suffixes=('_R', '_N'))

# %%
merged_df = pd.merge(regional_data, national_data, on=['Gender', 'ages from', 'ages to', 'Year', 'Quarter'], how='outer',suffixes=('_R', '_N'))

# %%
merged_df.head(5)
# Out:
#         Region   Gender  ages from  ages to  Year  \
# 0   Centro (I)  females         15       24  2004
# 1  Mezzogiorno  females         15       24  2004
# 2         Nord  females         15       24  2004
# 3     Nord-est  females         15       24  2004
# 4   Nord-ovest  females         15       24  2004
#
#    Yearly_TotalUnemploymentRate_R Quarter  Regional_UR Country  \
# 0                       25.647614     1.0    28.270221   Italy
# 1                       44.857174     1.0    45.920425   Italy
# 2                       15.191595     1.0    13.594228   Italy
# 3                       14.552232     1.0    13.104420   Italy
# 4                       15.685978     1.0    13.968358   Italy
#
#    Yearly_TotalUnemploymentRate_N  National_UR
# 0                       27.310948      27.5811
# 1                       27.310948      27.5811
# 2                       27.310948      27.5811
# 3                       27.310948      27.5811
# 4                       27.310948      27.5811

# %%
# Assuming merged_df is your DataFrame
merged_df = merged_df[['Country', 'Region', 'Gender', 'ages from', 'ages to', 'Year', 'Yearly_TotalUnemploymentRate_R', 'Yearly_TotalUnemploymentRate_N', 'Quarter', 'Regional_UR', 'National_UR']]

# %%
# Dropping the total rows from gender 
# We just want to the demographic information for analysis
# More helpful for analyzing crime rate

# %%
# Seperate it by Gender
gender_df = merged_df[merged_df['Gender'].isin(['males', 'females'])]

# %%
gender_df.head(5)
# Out:
#   Country       Region   Gender  ages from  ages to  Year  \
# 0   Italy   Centro (I)  females         15       24  2004
# 1   Italy  Mezzogiorno  females         15       24  2004
# 2   Italy         Nord  females         15       24  2004
# 3   Italy     Nord-est  females         15       24  2004
# 4   Italy   Nord-ovest  females         15       24  2004
#
#    Yearly_TotalUnemploymentRate_R  Yearly_TotalUnemploymentRate_N Quarter  \
# 0                       25.647614                       27.310948     1.0
# 1                       44.857174                       27.310948     1.0
# 2                       15.191595                       27.310948     1.0
# 3                       14.552232                       27.310948     1.0
# 4                       15.685978                       27.310948     1.0
#
#    Regional_UR  National_UR
# 0    28.270221      27.5811
# 1    45.920425      27.5811
# 2    13.594228      27.5811
# 3    13.104420      27.5811
# 4    13.968358      27.5811

# %%
gender_df.to_csv('quarterlyunemploymentbygender.csv', index=False)
